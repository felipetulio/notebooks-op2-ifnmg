# %% [markdown]
# # Fundamentos de Python para Ciência de Dados
# Python é uma das linguagens mais utilizadas em Ciência de Dados. Ela combina simplicidade e poder, oferecendo bibliotecas como **NumPy**, **Pandas** e **Matplotlib**, que permitem manipular, analisar e visualizar dados.
#
# Antes de explorarmos essas bibliotecas, precisamos entender os **fundamentos da linguagem**.

# %% [markdown]
# ## 🧮 Seção 2 — Criação e Atribuição de Variáveis
# Variáveis armazenam informações que podem ser reutilizadas e processadas. Em Ciência de Dados, costumamos armazenar medidas, nomes de colunas, contagens ou resultados de análises.

# %% [markdown]
# ## ⚙️ Seção 3 — Estruturas de Decisão (`if`, `elif`, `else`)
# Estruturas condicionais permitem **tomar decisões** usando condições (ou critérios) baseadas nos dados. Por exemplo, podemos verificar se a média de vendas está acima de uma meta.

# %% [markdown]
# ## 🔁 Seção 4 — Estruturas de Repetição (`for`, `while`)
# Laços (loops) de repetição permitem **iterar sobre coleções de dados** ou executar tarefas repetitivas. Em Ciência de Dados, isso é útil para percorrer listas, colunas ou registros.

# %% [markdown]
# ## 📋 Seção 5 — Listas
# Listas armazenam **coleções ordenadas de dados** e são essenciais em manipulação de conjuntos. Podemos guardar valores numéricos, nomes de colunas, resultados de análises etc.

# %% [markdown]
# ## 🗂️ Seção 6 — Dicionários
# Dicionários armazenam **pares de chave e valor**, úteis para representar dados tabulares ou metadados (ex: nome da coluna e tipo de dado).

# %% [markdown]
# ## 📊 Seção 7 — Integração de Conceitos: Análise de Dados Simples
# Vamos juntar os conceitos anteriores em um mini exemplo de análise. Simularemos um conjunto de dados de vendas para analisar o total de faturamento, além de descobrir quais produtos estão acima dos R$ 100,00.
